# %%
# -*- coding: utf-8 -*-
__author__ = 'Seran'
 
import cv2
 
# 영상의 의미지를 연속적으로 캡쳐할 수 있게 하는 class
vidcap = cv2.VideoCapture('./movie/Desktop 2020.06.17 - 12.52.39.01.mp4')
 
count = 0
 
while(vidcap.isOpened()):
    # read()는 grab()와 retrieve() 두 함수를 한 함수로 불러옴
    # 두 함수를 동시에 불러오는 이유는 프레임이 존재하지 않을 때
    # grab() 함수를 이용하여 return false 혹은 NULL 값을 넘겨 주기 때문
    ret, image = vidcap.read()
 
    if(int(vidcap.get(1)) % 20 == 0):
        print('Saved frame number : ' + str(int(vidcap.get(1))))
        cv2.imwrite("./images/frame%d.jpg" % count, image)
        print('Saved frame%d.jpg' % count)
        count += 1
        
vidcap.release()
# Out:
# 7920
# Saved frame3395.jpg
# Saved frame number : 67940
# Saved frame3396.jpg
# Saved frame number : 67960
# Saved frame3397.jpg
# Saved frame number : 67980
# Saved frame3398.jpg
# Saved frame number : 68000
# Saved frame3399.jpg
# Saved frame number : 68020
# Saved frame3400.jpg
# Saved frame number : 68040
# Saved frame3401.jpg
# Saved frame number : 68060
# Saved frame3402.jpg
# Saved frame number : 68080
# Saved frame3403.jpg
# Saved frame number : 68100
# Saved frame3404.jpg
# Saved frame number : 68120
# Saved frame3405.jpg
# Saved frame number : 68140
# Saved frame3406.jpg
# Saved frame number : 68160
# Saved frame3407.jpg
# Saved frame number : 68180
# Saved frame3408.jpg
# Saved frame number : 68200
# Saved frame3409.jpg
# Saved frame number : 68220
# Saved frame3410.jpg
# Saved frame number : 68240
# Saved frame3411.jpg
# Saved frame number : 68260
# Saved frame3412.jpg
# Saved frame number : 68280
# Saved frame3413.jpg
# Saved frame number : 68300
# Saved frame3414.jpg
# Saved frame number : 68320
# Saved frame3415.jpg
# Saved frame number : 68340
# Saved frame3416.jpg
# Saved frame number : 68360
# Saved frame3417.jpg
# Saved frame number : 68380
# Saved frame3418.jpg
# Saved frame number : 68400
# Saved frame3419.jpg
# Saved frame number : 68420
# Saved frame3420.jpg
# Saved frame number : 68440
# Saved frame3421.jpg
# Saved frame number : 68460
# Saved frame3422.jpg
# Saved frame number : 68480
# Saved frame3423.jpg
# Saved frame number : 68500
# Saved frame3424.jpg
# Saved frame number : 68520
# Saved frame3425.jpg
# Saved frame number : 68540
# Saved frame3426.jpg
# Saved frame number : 68560
# Saved frame3427.jpg
# Saved frame number : 68580
# Saved frame3428.jpg
# Saved frame number : 68600
# Saved frame3429.jpg
# Saved frame number : 68620
# Saved frame3430.jpg
# Saved frame number : 68640
# Saved frame3431.jpg
# Saved frame number : 68660
# Saved frame3432.jpg
# Saved frame number : 68680
# Saved frame3433.jpg
# Saved frame number : 68700
# Saved frame3434.jpg
# Saved frame number : 68720
# Saved frame3435.jpg
# Saved frame number : 68740
# Saved frame3436.jpg
# Saved frame number : 68760
# Saved frame3437.jpg
# Saved frame number : 68780
# Saved frame3438.jpg
# Saved frame number : 68800
# Saved frame3439.jpg
# Saved frame number : 68820
# Saved frame3440.jpg
# Saved frame number : 68840
# Saved frame3441.jpg
# Saved frame number : 68860
# Saved frame3442.jpg
# Saved frame number : 68880
# Saved frame3443.jpg
# Saved frame number : 68900
# Saved frame3444.jpg
# Saved frame number : 68920
# Saved frame3445.jpg
# Saved frame number : 68940
# Saved frame3446.jpg
# Saved frame number : 68960
# Saved frame3447.jpg
# Saved frame number : 68980
# Saved frame3448.jpg
# Saved frame number : 69000
# Saved frame3449.jpg
# Saved frame number : 69020
# Saved frame3450.jpg
# Saved frame number : 69040
# Saved frame3451.jpg
# Saved frame number : 69060
# Saved frame3452.jpg
# Saved frame number : 69080
# Saved frame3453.jpg
# Saved frame number : 69100
# Saved frame3454.jpg
# Saved frame number : 69120
# Saved frame3455.jpg
# Saved frame number : 69140
# Saved frame3456.jpg
# Saved frame number : 69160
# Saved frame3457.jpg
# Saved frame number : 69180
# Saved frame3458.jpg
# Saved frame number : 69200
# Saved frame3459.jpg
# Saved frame number : 69220
# Saved frame3460.jpg
# Saved frame number : 69240
# Saved frame3461.jpg
# Saved frame number : 69260
# Saved frame3462.jpg
# Saved frame number : 69280
# Saved frame3463.jpg
# Saved frame number : 69300
# Saved frame3464.jpg
# Saved frame number : 69320
# Saved frame3465.jpg
# Saved frame number : 69340
# Saved frame3466.jpg
# Saved frame number : 69360
# Saved frame3467.jpg
# Saved frame number : 69380
# Saved frame3468.jpg
# Saved frame number : 69400
# Saved frame3469.jpg
# Saved frame number : 69420
# Saved frame3470.jpg
# Saved frame number : 69440
# Saved frame3471.jpg
# Saved frame number : 69460
# Saved frame3472.jpg
# Saved frame number : 69480
# Saved frame3473.jpg
# Saved frame number : 69500
# Saved frame3474.jpg
# Saved frame number : 69520
# Saved frame3475.jpg
# Saved frame number : 69540
# Saved frame3476.jpg
# Saved frame number : 69560
# Saved frame3477.jpg
# Saved frame number : 69580
# Saved frame3478.jpg
# Saved frame number : 69600
# Saved frame3479.jpg
# Saved frame number : 69620
# Saved frame3480.jpg
# Saved frame number : 69640
# Saved frame3481.jpg
# Saved frame number : 69660
# Saved frame3482.jpg
# Saved frame number : 69680
# Saved frame3483.jpg
# Saved frame number : 69700
# Saved frame3484.jpg
# Saved frame number : 69720
# Saved frame3485.jpg
# Saved frame number : 69740
# Saved frame3486.jpg
# Saved frame number : 69760
# Saved frame3487.jpg
# Saved frame number : 69780
# Saved frame3488.jpg
# Saved frame number : 69800
# Saved frame3489.jpg
# Saved frame number : 69820
# Saved frame3490.jpg
# Saved frame number : 69840
# Saved frame3491.jpg
# Saved frame number : 69860
# Saved frame3492.jpg
# Saved frame number : 69880
# Saved frame3493.jpg
# Saved frame number : 69900
# Saved frame3494.jpg
# Saved frame number : 69920
# Saved frame3495.jpg
# Saved frame number : 69940
# Saved frame3496.jpg
# Saved frame number : 69960
# Saved frame3497.jpg
# Saved frame number : 69980
# Saved frame3498.jpg
# Saved frame number : 70000
# Saved frame3499.jpg
# Saved frame number : 70020
# Saved frame3500.jpg
# Saved frame number : 70040
# Saved frame3501.jpg
# Saved frame number : 70060
# Saved frame3502.jpg
# Saved frame number : 70080
# Saved frame3503.jpg
# Saved frame number : 70100
# Saved frame3504.jpg
# Saved frame number : 70120
# Saved frame3505.jpg
# Saved frame number : 70140
# Saved frame3506.jpg
# Saved frame number : 70160
# Saved frame3507.jpg
# Saved frame number : 70180
# Saved frame3508.jpg
# Saved frame number : 70200
# Saved frame3509.jpg
# Saved frame number : 70220
# Saved frame3510.jpg
# Saved frame number : 70240
# Saved frame3511.jpg
# Saved frame number : 70260
# Saved frame3512.jpg
# Saved frame number : 70280
# Saved frame3513.jpg
# Saved frame number : 70300
# Saved frame3514.jpg
# Saved frame number : 70320
# Saved frame3515.jpg
# Saved frame number : 70340
# Saved frame3516.jpg
# Saved frame number : 70360
# Saved frame3517.jpg
# Saved frame number : 70380
# Saved frame3518.jpg
# Saved frame number : 70400
# Saved frame3519.jpg
# Saved frame number : 70420
# Saved frame3520.jpg
# Saved frame number : 70440
# Saved frame3521.jpg
# Saved frame number : 70460
# Saved frame3522.jpg
# Saved frame number : 70480
# Saved frame3523.jpg
# Saved frame number : 70500
# Saved frame3524.jpg
# Saved frame number : 70520
# Saved frame3525.jpg
# Saved frame number : 70540
# Saved frame3526.jpg
# Saved frame number : 70560
# Saved frame3527.jpg
# Saved frame number : 70580
# Saved frame3528.jpg
# Saved frame number : 70600
# Saved frame3529.jpg
# Saved frame number : 70620
# Saved frame3530.jpg
# Saved frame number : 70640
# Saved frame3531.jpg
# Saved frame number : 70660
# Saved frame3532.jpg
# Saved frame number : 70680
# Saved frame3533.jpg
# Saved frame number : 70700
# Saved frame3534.jpg
# Saved frame number : 70720
# Saved frame3535.jpg
# Saved frame number : 70740
# Saved frame3536.jpg
# Saved frame number : 70760
# Saved frame3537.jpg
# Saved frame number : 70780
# Saved frame3538.jpg
# Saved frame number : 70800
# Saved frame3539.jpg
# Saved frame number : 70820
# Saved frame3540.jpg
# Saved frame number : 70840
# Saved frame3541.jpg
# Saved frame number : 70860
# Saved frame3542.jpg
# Saved frame number : 70880
# Saved frame3543.jpg
# Saved frame number : 70900
# Saved frame3544.jpg
# Saved frame number : 70920
# Saved frame3545.jpg
# Saved frame number : 70940
# Saved frame3546.jpg
# Saved frame number : 70960
# Saved frame3547.jpg
# Saved frame number : 70980
# Saved frame3548.jpg
# Saved frame number : 71000
# Saved frame3549.jpg
# Saved frame number : 71020
# Saved frame3550.jpg
# Saved frame number : 71040
# Saved frame3551.jpg
# Saved frame number : 71060
# Saved frame3552.jpg
# Saved frame number : 71080
# Saved frame3553.jpg
# Saved frame number : 71100
# Saved frame3554.jpg
# Saved frame number : 71120
# Saved frame3555.jpg
# Saved frame number : 71140
# Saved frame3556.jpg
# Saved frame number : 71160
# Saved frame3557.jpg
# Saved frame number : 71180
# Saved frame3558.jpg
# Saved frame number : 71200
# Saved frame3559.jpg
# Saved frame number : 71220
# Saved frame3560.jpg
# Saved frame number : 71240
# Saved frame3561.jpg
# Saved frame number : 71260
# Saved frame3562.jpg
# Saved frame number : 71280
# Saved frame3563.jpg
# Saved frame number : 71300
# Saved frame3564.jpg
# Saved frame number : 71320
# Saved frame3565.jpg
# Saved frame number : 71340
# Saved frame3566.jpg
# Saved frame number : 71360
# Saved frame3567.jpg
# Saved frame number : 71380
# Saved frame3568.jpg
# Saved frame number : 71400
# Saved frame3569.jpg
# Saved frame number : 71420
# Saved frame3570.jpg
# Saved frame number : 71440
# Saved frame3571.jpg
# Saved frame number : 71460
# Saved frame3572.jpg
# Saved frame number : 71480
# Saved frame3573.jpg
# Saved frame number : 71500
# Saved frame3574.jpg
# Saved frame number : 71520
# Saved frame3575.jpg
# Saved frame number : 71540
# Saved frame3576.jpg
# Saved frame number : 71560
# Saved frame3577.jpg
# Saved frame number : 71580
# Saved frame3578.jpg
# Saved frame number : 71600
# Saved frame3579.jpg
# Saved frame number : 71620
# Saved frame3580.jpg
# Saved frame number : 71640
# Saved frame3581.jpg
# Saved frame number : 71660
# Saved frame3582.jpg
# Saved frame number : 71680
# Saved frame3583.jpg
# Saved frame number : 71700
# Saved frame3584.jpg
# Saved frame number : 71720
# Saved frame3585.jpg
# Saved frame number : 71740
# Saved frame3586.jpg
# Saved frame number : 71760
# Saved frame3587.jpg
# Saved frame number : 71780
# Saved frame3588.jpg
# Saved frame number : 71800
# Saved frame3589.jpg
# Saved frame number : 71820
# Saved frame3590.jpg
# Saved frame number : 71840
# Saved frame3591.jpg
# Saved frame number : 71860
# Saved frame3592.jpg
# Saved frame number : 71880
# Saved frame3593.jpg
# Saved frame number : 71900
# Saved frame3594.jpg
# Saved frame number : 71920
# Saved frame3595.jpg
# Saved frame number : 71940
# Saved frame3596.jpg
# Saved frame number : 71960
# Saved frame3597.jpg
# Saved frame number : 71980
# Saved frame3598.jpg
# Saved frame number : 72000
# Saved frame3599.jpg
# Saved frame number : 72020
# Saved frame3600.jpg
# Saved frame number : 72040
# Saved frame3601.jpg
# Saved frame number : 72060
# Saved frame3602.jpg
# Saved frame number : 72080
# Saved frame3603.jpg
# Saved frame number : 72100
# Saved frame3604.jpg
# Saved frame number : 72120
# Saved frame3605.jpg
# Saved frame number : 72140
# Saved frame3606.jpg
# Saved frame number : 72160
# Saved frame3607.jpg
# Saved frame number : 72180
# Saved frame3608.jpg
# Saved frame number : 72200
# Saved frame3609.jpg
# Saved frame number : 72220
# Saved frame3610.jpg
# Saved frame number : 72240
# Saved frame3611.jpg
# Saved frame number : 72260
# Saved frame3612.jpg
# Saved frame number : 72280
# Saved frame3613.jpg
# Saved frame number : 72300
# Saved frame3614.jpg
# Saved frame number : 72320
# Saved frame3615.jpg
# Saved frame number : 72340
# Saved frame3616.jpg
# Saved frame number : 72360
# Saved frame3617.jpg
# Saved frame number : 72380
# Saved frame3618.jpg
# Saved frame number : 72400
# Saved frame3619.jpg
# Saved frame number : 72420
# Saved frame3620.jpg
# Saved frame number : 72440
# Saved frame3621.jpg
# Saved frame number : 72460
# Saved frame3622.jpg
# Saved frame number : 72480
# Saved frame3623.jpg
# Saved frame number : 72500
# Saved frame3624.jpg
# Saved frame number : 72520
# Saved frame3625.jpg
# Saved frame number : 72540
# Saved frame3626.jpg
# Saved frame number : 72560
# Saved frame3627.jpg
# Saved frame number : 72580
# Saved frame3628.jpg
# Saved frame number : 72600
# Saved frame3629.jpg
# Saved frame number : 72620
# Saved frame3630.jpg
# Saved frame number : 72640
# Saved frame3631.jpg
# Saved frame number : 72660
# Saved frame3632.jpg
# Saved frame number : 72680
# Saved frame3633.jpg
# Saved frame number : 72700
# Saved frame3634.jpg
# Saved frame number : 72720
# Saved frame3635.jpg
# Saved frame number : 72740
# Saved frame3636.jpg
# Saved frame number : 72760
# Saved frame3637.jpg
# Saved frame number : 72780
# Saved frame3638.jpg
# Saved frame number : 72800
# Saved frame3639.jpg
# Saved frame number : 72820
# Saved frame3640.jpg
# Saved frame number : 72840
# Saved frame3641.jpg
# Saved frame number : 72860
# Saved frame3642.jpg
# Saved frame number : 72880
# Saved frame3643.jpg
# Saved frame number : 72900
# Saved frame3644.jpg
# Saved frame number : 72920
# Saved frame3645.jpg
# Saved frame number : 72940
# Saved frame3646.jpg
# Saved frame number : 72960
# Saved frame3647.jpg
# Saved frame number : 72980
# Saved frame3648.jpg
# Saved frame number : 73000
# Saved frame3649.jpg
# Saved frame number : 73020
# Saved frame3650.jpg
# Saved frame number : 73040
# Saved frame3651.jpg
# Saved frame number : 73060
# Saved frame3652.jpg
# Saved frame number : 73080
# Saved frame3653.jpg
# Saved frame number : 73100
# Saved frame3654.jpg
# Saved frame number : 73120
# Saved frame3655.jpg
# Saved frame number : 73140
# Saved frame3656.jpg
# Saved frame number : 73160
# Saved frame3657.jpg
# Saved frame number : 73180
# Saved frame3658.jpg
# Saved frame number : 73200
# Saved frame3659.jpg
# Saved frame number : 73220
# Saved frame3660.jpg
# Saved frame number : 73240
# Saved frame3661.jpg
# Saved frame number : 73260
# Saved frame3662.jpg
# Saved frame number : 73280
# Saved frame3663.jpg
# Saved frame number : 73300
# Saved frame3664.jpg
# Saved frame number : 73320
# Saved frame3665.jpg
# Saved frame number : 73340
# Saved frame3666.jpg
# Saved frame number : 73360
# Saved frame3667.jpg
# Saved frame number : 73380
# Saved frame3668.jpg
# Saved frame number : 73400
# Saved frame3669.jpg
# Saved frame number : 73420
# Saved frame3670.jpg
# Saved frame number : 73440
# Saved frame3671.jpg
# Saved frame number : 73460
# Saved frame3672.jpg
# Saved frame number : 73480
# Saved frame3673.jpg
# Saved frame number : 73500
# Saved frame3674.jpg
# Saved frame number : 73520
# Saved frame3675.jpg
# Saved frame number : 73540
# Saved frame3676.jpg
# Saved frame number : 73560
# Saved frame3677.jpg
# Saved frame number : 73580
# Saved frame3678.jpg
# Saved frame number : 73600
# Saved frame3679.jpg
# Saved frame number : 73620
# Saved frame3680.jpg
# Saved frame number : 73640
# Saved frame3681.jpg
# Saved frame number : 73660
# Saved frame3682.jpg
# Saved frame number : 73680
# Saved frame3683.jpg
# Saved frame number : 73700
# Saved frame3684.jpg
# Saved frame number : 73720
# Saved frame3685.jpg
# Saved frame number : 73740
# Saved frame3686.jpg
# Saved frame number : 73760
# Saved frame3687.jpg
# Saved frame number : 73780
# Saved frame3688.jpg
# Saved frame number : 73800
# Saved frame3689.jpg
# Saved frame number : 73820
# Saved frame3690.jpg
# Saved frame number : 73840
# Saved frame3691.jpg
# Saved frame number : 73860
# Saved frame3692.jpg
# Saved frame number : 73880
# Saved frame3693.jpg
# Saved frame number : 73900
# Saved frame3694.jpg
# Saved frame number : 73920
# Saved frame3695.jpg
# Saved frame number : 73940
# Saved frame3696.jpg
# Saved frame number : 73960
# Saved frame3697.jpg
# Saved frame number : 73980
# Saved frame3698.jpg
# Saved frame number : 74000
# Saved frame3699.jpg
# Saved frame number : 74020
# Saved frame3700.jpg
# Saved frame number : 74040
# Saved frame3701.jpg
# Saved frame number : 74060
# Saved frame3702.jpg
# Saved frame number : 74080
# Saved frame3703.jpg
# Saved frame number : 74100
# Saved frame3704.jpg
# Saved frame number : 74120
# Saved frame3705.jpg
# Saved frame number : 74140
# Saved frame3706.jpg
# Saved frame number : 74160
# Saved frame3707.jpg
# Saved frame number : 74180
# Saved frame3708.jpg
# Saved frame number : 74200
# Saved frame3709.jpg
# Saved frame number : 74220
# Saved frame3710.jpg
# Saved frame number : 74240
# Saved frame3711.jpg
# Saved frame number : 74260
# Saved frame3712.jpg
# Saved frame number : 74280
# Saved frame3713.jpg
# Saved frame number : 74300
# Saved frame3714.jpg
# Saved frame number : 74320
# Saved frame3715.jpg
# Saved frame number : 74340
# Saved frame3716.jpg
# Saved frame number : 74360
# Saved frame3717.jpg
# Saved frame number : 74380
# Saved frame3718.jpg
# Saved frame number : 74400
# Saved frame3719.jpg
# Saved frame number : 74420
# Saved frame3720.jpg
# Saved frame number : 74440
# Saved frame3721.jpg
# Saved frame number : 74460
# Saved frame3722.jpg
# Saved frame number : 74480
# Saved frame3723.jpg
# Saved frame number : 74500
# Saved frame3724.jpg
# Saved frame number : 74520
# Saved frame3725.jpg
# Saved frame number : 74540
# Saved frame3726.jpg
# Saved frame number : 74560
# Saved frame3727.jpg
# Saved frame number : 74580
# Saved frame3728.jpg
# Saved frame number : 74600
# Saved frame3729.jpg
# Saved frame number : 74620
# Saved frame3730.jpg
# Saved frame number : 74640
# Saved frame3731.jpg
# Saved frame number : 74660
# Saved frame3732.jpg
# Saved frame number : 74680
# Saved frame3733.jpg
# Saved frame number : 74700
# Saved frame3734.jpg
# Saved frame number : 74720
# Saved frame3735.jpg
# Saved frame number : 74740
# Saved frame3736.jpg
# Saved frame number : 74760
# Saved frame3737.jpg
# Saved frame number : 74780
# Saved frame3738.jpg
# Saved frame number : 74800
# Saved frame3739.jpg
# Saved frame number : 74820
# Saved frame3740.jpg
# Saved frame number : 74840
# Saved frame3741.jpg
# Saved frame number : 74860
# Saved frame3742.jpg
# Saved frame number : 74880
# Saved frame3743.jpg
# Saved frame number : 74900
# Saved frame3744.jpg
# Saved frame number : 74920
# Saved frame3745.jpg
# Saved frame number : 74940
# Saved frame3746.jpg
# Saved frame number : 74960
# Saved frame3747.jpg
# Saved frame number : 74980
# Saved frame3748.jpg
# Saved frame number : 75000
# Saved frame3749.jpg
# Saved frame number : 75020
# Saved frame3750.jpg
# Saved frame number : 75040
# Saved frame3751.jpg
# Saved frame number : 75060
# Saved frame3752.jpg
# Saved frame number : 75080
# Saved frame3753.jpg
# Saved frame number : 75100
# Saved frame3754.jpg
# Saved frame number : 75120
# Saved frame3755.jpg
# Saved frame number : 75140
# Saved frame3756.jpg
# Saved frame number : 75160
# Saved frame3757.jpg
# Saved frame number : 75180
# Saved frame3758.jpg
# Saved frame number : 75200
# Saved frame3759.jpg
# Saved frame number : 75220
# Saved frame3760.jpg
# Saved frame number : 75240
# Saved frame3761.jpg
# Saved frame number : 75260
# Saved frame3762.jpg
# Saved frame number : 75280
# Saved frame3763.jpg
# Saved frame number : 75300
# Saved frame3764.jpg
# Saved frame number : 75320
# Saved frame3765.jpg
# Saved frame number : 75340
# Saved frame3766.jpg
# Saved frame number : 75360
# Saved frame3767.jpg
# Saved frame number : 75380
# Saved frame3768.jpg
# Saved frame number : 75400
# Saved frame3769.jpg
# Saved frame number : 75420
# Saved frame3770.jpg
# Saved frame number : 75440
# Saved frame3771.jpg
# Saved frame number : 75460
# Saved frame3772.jpg
# Saved frame number : 75480
# Saved frame3773.jpg
# Saved frame number : 75500
# Saved frame3774.jpg
# Saved frame number : 75520
# Saved frame3775.jpg
# Saved frame number : 75540
# Saved frame3776.jpg
# Saved frame number : 75560
# Saved frame3777.jpg
# Saved frame number : 75580
# Saved frame3778.jpg
# Saved frame number : 75600
# Saved frame3779.jpg
# Saved frame number : 75620
# Saved frame3780.jpg
# Saved frame number : 75640
# Saved frame3781.jpg
# Saved frame number : 75660
# Saved frame3782.jpg
# Saved frame number : 75680
# Saved frame3783.jpg
# Saved frame number : 75700
# Saved frame3784.jpg
# Saved frame number : 75720
# Saved frame3785.jpg
# Saved frame number : 75740
# Saved frame3786.jpg
# Saved frame number : 75760
# Saved frame3787.jpg
# Saved frame number : 75780
# Saved frame3788.jpg
# Saved frame number : 75800
# Saved frame3789.jpg
# Saved frame number : 75820
# Saved frame3790.jpg
# Saved frame number : 75840
# Saved frame3791.jpg
# Saved frame number : 75860
# Saved frame3792.jpg
# Saved frame number : 75880
# Saved frame3793.jpg
# Saved frame number : 75900
# Saved frame3794.jpg
# Saved frame number : 75920
# Saved frame3795.jpg
# Saved frame number : 75940
# Saved frame3796.jpg
# Saved frame number : 75960
# Saved frame3797.jpg
# Saved frame number : 75980
# Saved frame3798.jpg
# Saved frame number : 76000
# Saved frame3799.jpg
# Saved frame number : 76020
# Saved frame3800.jpg
# Saved frame number : 76040
# Saved frame3801.jpg
# Saved frame number : 76060
# Saved frame3802.jpg
# Saved frame number : 76080
# Saved frame3803.jpg
# Saved frame number : 76100
# Saved frame3804.jpg
# Saved frame number : 76120
# Saved frame3805.jpg
# Saved frame number : 76140
# Saved frame3806.jpg
# Saved frame number : 76160
# Saved frame3807.jpg
# Saved frame number : 76180
# Saved frame3808.jpg
# Saved frame number : 76200
# Saved frame3809.jpg
# Saved frame number : 76220
# Saved frame3810.jpg
# Saved frame number : 76240
# Saved frame3811.jpg
# Saved frame number : 76260
# Saved frame3812.jpg
# Saved frame number : 76280
# Saved frame3813.jpg
# Saved frame number : 76300
# Saved frame3814.jpg
# Saved frame number : 76320
# Saved frame3815.jpg
# Saved frame number : 76340
# Saved frame3816.jpg
# Saved frame number : 76360
# Saved frame3817.jpg
# Saved frame number : 76380
# Saved frame3818.jpg
# Saved frame number : 76400
# Saved frame3819.jpg
# Saved frame number : 76420
# Saved frame3820.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-8d493eea059b> in <module>
#      13     # 두 함수를 동시에 불러오는 이유는 프레임이 존재하지 않을 때
#      14     # grab() 함수를 이용하여 return false 혹은 NULL 값을 넘겨 주기 때문
# ---> 15     ret, image = vidcap.read()
#      16
#      17     if(int(vidcap.get(1)) % 20 == 0):
#
# KeyboardInterrupt:
